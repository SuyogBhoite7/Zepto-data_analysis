# %%
import pandas as pd

df = pd.read_csv("zepto_v2.csv", encoding="latin1")

# %%
df.head(5)
# Out:
#               Category              name   mrp  discountPercent  \
# 0  Fruits & Vegetables             Onion  2500               16
# 1  Fruits & Vegetables     Tomato Hybrid  4200               16
# 2  Fruits & Vegetables    Tender Coconut  5100               15
# 3  Fruits & Vegetables  Coriander Leaves  2000               15
# 4  Fruits & Vegetables    Ladies Finger   1400               14
#
#    availableQuantity  discountedSellingPrice  weightInGms  outOfStock  \
# 0                  3                    2100         1000       False
# 1                  3                    3500         1000       False
# 2                  3                    4300           58       False
# 3                  3                    1700          100       False
# 4                  3                    1200          250       False
#
#    quantity
# 0         1
# 1         1
# 2         1
# 3       100
# 4       250

# %%
# !pip install psycopg2-binary sqlalchemy
# Out:
# Requirement already satisfied: psycopg2-binary in c:\python313\lib\site-packages (2.9.11)
# Requirement already satisfied: sqlalchemy in c:\python313\lib\site-packages (2.0.48)
# Requirement already satisfied: greenlet>=1 in c:\python313\lib\site-packages (from sqlalchemy) (3.3.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\python313\lib\site-packages (from sqlalchemy) (4.15.0)
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install pymysql sqlalchemy
# Out:
# Requirement already satisfied: pymysql in c:\python313\lib\site-packages (1.1.2)
# Requirement already satisfied: sqlalchemy in c:\python313\lib\site-packages (2.0.48)
# Requirement already satisfied: greenlet>=1 in c:\python313\lib\site-packages (from sqlalchemy) (3.3.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\python313\lib\site-packages (from sqlalchemy) (4.15.0)
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sqlalchemy import create_engine

# %%
from sqlalchemy import create_engine

# MySQL connection
engine_mysql = create_engine(
    "mysql+pymysql://root:Naruto%408652@localhost:3306/zepto"
)

try:
    engine_mysql.connect()
    print("MySQL Connected Successfully")
except Exception as e:
    print("Connection failed:", e)
# Out:
# MySQL Connected Successfully

# %%
import pandas as pd

# %%
df.to_sql(name='zepto_v2', con=engine_mysql, if_exists='append', index=False)
# Out:
# 3732
